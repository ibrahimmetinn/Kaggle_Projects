# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\ibrah\Datasets\onlinefoods\onlinefoods.csv")

# %% [markdown]
# # EDA Analysis

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
df.describe().T
# Out:
#              count           mean        std          min            25%  \
# Age          388.0      24.628866   2.975593      18.0000      23.000000
# Family size  388.0       3.280928   1.351025       1.0000       2.000000
# latitude     388.0      12.972058   0.044489      12.8652      12.936900
# longitude    388.0      77.600160   0.051354      77.4842      77.565275
# Pin code     388.0  560040.113402  31.399609  560001.0000  560010.750000
#
#                      50%            75%          max
# Age              24.0000      26.000000      33.0000
# Family size       3.0000       4.000000       6.0000
# latitude         12.9770      12.997025      13.1020
# longitude        77.5921      77.630900      77.7582
# Pin code     560033.5000  560068.000000  560109.0000

# %%
plt.figure(figsize=(10, 6))
plt.title('Age Distribution')
sns.distplot(df["Age"])
plt.text(x=15, y=-0.05, s="Grafik sola çarpık gözüküyor. (positively skewed)", fontsize=12, color='red')
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_4592\1773713172.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])

# %%
df["Age"].mode()
# Out:
# 0    23
# Name: Age, dtype: int64

# %%
df["Age"].median()
# Out:
# 24.0

# %%
df["Age"].mean()
# Out:
# 24.628865979381445

# %%
plt.figure(figsize=(10, 6))
plt.title('Family Size Distribution')
sns.distplot(df["Family size"]);
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_4592\1541223137.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Family size"]);

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %% [markdown]
# # Mountly Income Statistic

# %%
df["Gender"]=pd.Categorical(df["Gender"])

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
# Sort Categories
kategori_sirasi = ['No Income', 'Below Rs.10000', '10001 to 25000', '25001 to 50000', 'More than 50000']
df['Monthly Income'] = pd.Categorical(df['Monthly Income'], categories=kategori_sirasi, ordered=True)

# %%
df1=df

# %% [markdown]
# #### Output Column same Unnamed 12

# %%
df1.drop(columns="Unnamed: 12",inplace=True)

# %%
df1
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %% [markdown]
# # Functions

# %% [markdown]
# ### The function created to evaluate the other criteria according to the monthly income scale

# %%
# X= any column name in the dataframe 
def mountly_income(X):
    plt.figure(figsize=(10,6))
    plt.title(str(X)+" in Mounthly İncome Statistic")
    grouped_data = df1.groupby(X)["Monthly Income"].value_counts().reset_index(name="Count")
    sns.barplot(data=grouped_data, x="Monthly Income", y="Count", hue=X)

# %% [markdown]
# ### Pie chart function

# %%
def pie_chart(P):
    plt.figure(figsize=(10,6))
    explode = [0.1 for _ in range(len(df1[P].unique()))]  
    palette_color = sns.color_palette('deep') 
    plt.pie(df1[P].value_counts(), labels=df1[P].unique(), colors=palette_color, 
            explode=explode, autopct='%.0f%%') 
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title("Mountly Income Statistic")
sns.barplot(x=df["Monthly Income"].value_counts().index,y=df["Monthly Income"].value_counts());

# %% [markdown]
# ### Male Female in Mountly İcome Statistic

# %%
mountly_income("Gender")

# %% [markdown]
# ### Age Statistic

# %%
df1["Age"].value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %% [markdown]
# ### Marital Status in Mountly İcome Statistic

# %%
df["Monthly Income"].value_counts()
# Out:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64

# %%
pie_chart("Marital Status")

# %%
mountly_income("Marital Status")

# %% [markdown]
# ### Occupation in Mountly İcome Statistic

# %%
df1["Occupation"].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
pie_chart("Occupation")

# %%
mountly_income("Occupation")

# %% [markdown]
# ### Educational Qualifications in Mountly İcome Statistic

# %%
df1["Educational Qualifications"].value_counts()
# Out:
# Educational Qualifications
# Graduate         177
# Post Graduate    174
# Ph.D              23
# School            12
# Uneducated         2
# Name: count, dtype: int64

# %%
#pie chart function
pie_chart("Educational Qualifications")

# %%
mountly_income("Educational Qualifications")

# %% [markdown]
# ### Family size in Mountly İncome Statistic

# %%
pie_chart("Family size")

# %%
mountly_income("Family size")

# %% [markdown]
# # Statistic On Map

# %%
df1.head()

# %%
import folium

#Map Center
center_lat = df1['latitude'].mean()
center_lon = df1['longitude'].mean()
map1 = folium.Map(location=[center_lat, center_lon], zoom_start=5)

# Add location on map
for i in range(len(df1)):
    folium.Marker(
        location=[df1.iloc[i]['latitude'], df1.iloc[i]['longitude']]
    ).add_to(map1)

# Map Show
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Output Statistic

# %%
df1.shape
# Out:
# (388, 13)

# %%
df1.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
pie_chart("Output")  
pie_chart("Feedback")

# %% [markdown]
# # Machine Learning

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
df1.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback'],
#       dtype='object')

# %%
df3=df1.copy()

# %%
df3["Monthly Income"].value_counts()
# Out:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64

# %%
#Encoding
df3['Gender_Encoded'] = df3['Gender'].map({'Male': 1, 'Female': 0})
df3["Marital_Status_Encoded"]=df3['Marital Status'].map({'Single':0,'Married':1,"Prefer not to say":3})
df3["Occupation_Encoded"]=df3['Occupation'].map({'Student':0,'Employee':1,"Self Employeed":3,"House wife":4})
df3["EQ_Encoded"]=df3['Educational Qualifications'].map({'Uneducated':0,'School':1,"Graduate":2,"Post Graduate":3,"Ph.D":4})
df3["MI_Encoded"]=df3['Monthly Income'].map({'No Income':0,'Below Rs.10000':5000,"10001 to 25000":17500,"25001 to 50000":37500,"More than 50000":60000})

# %%
df3["MI_Encoded"].value_counts()
# Out:
# MI_Encoded
# 0        187
# 37500     69
# 60000     62
# 17500     45
# 5000      25
# Name: count, dtype: int64

# %%
df3.describe().T
# Out:
#                         count           mean        std          min  \
# Age                     388.0      24.628866   2.975593      18.0000
# Family size             388.0       3.280928   1.351025       1.0000
# latitude                388.0      12.972058   0.044489      12.8652
# longitude               388.0      77.600160   0.051354      77.4842
# Pin code                388.0  560040.113402  31.399609  560001.0000
# Marital_Status_Encoded  388.0       0.371134   0.648107       0.0000
# Occupation_Encoded      388.0       0.814433   1.125967       0.0000
# EQ_Encoded              388.0       2.525773   0.679607       0.0000
#
#                                   25%          50%            75%          max
# Age                         23.000000      24.0000      26.000000      33.0000
# Family size                  2.000000       3.0000       4.000000       6.0000
# latitude                    12.936900      12.9770      12.997025      13.1020
# ...

# %% [markdown]
# ## DecisionTreeRegressor

# %%
y=df3["MI_Encoded"]
features = ['Age','Gender_Encoded','Marital_Status_Encoded', 'Occupation_Encoded','EQ_Encoded','Family size']
X=df3[features]
## Split into validation and training data
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
# Specify Model
iowa_model = DecisionTreeRegressor(random_state=1)
# Fit Model
iowa_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE when not specifying max_leaf_nodes: {:,.0f}".format(val_mae))
# Out:
# Validation MAE when not specifying max_leaf_nodes: 6,901

# %%
iowa_model = DecisionTreeRegressor(max_leaf_nodes=100,random_state=1)
iowa_model.fit(train_X, train_y)
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))
# Out:
# Validation MAE for best value of max_leaf_nodes: 7,133

# %%
rmse = np.sqrt(val_mae)
print("Validation RMSE: {:.2f}".format(rmse))
# Out:
# Validation RMSE: 84.46

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Define the model. Set random_state to 1
rf_model = RandomForestRegressor(random_state=1)

# fit your model
rf_model.fit(train_X,train_y)

# Calculate the mean absolute error of your Random Forest model on the validation data
rf_val_mae = rf_model.predict(val_X)

print("Validation MAE for Random Forest Model: {}".format(mean_absolute_error(val_y,rf_val_mae)))
# Out:
# Validation MAE for Random Forest Model: 7506.638173538947

# %%
rmse1 = np.sqrt(mean_absolute_error(val_y,rf_val_mae))
print("Validation RMSE: {:.2f}".format(rmse1))
# Out:
# Validation RMSE: 86.64
